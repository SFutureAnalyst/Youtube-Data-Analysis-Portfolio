# %% [markdown]
# # <h1 style="text-align:center; color:black;">PYTHON GRADED PROJECT</h1>

# %% [markdown]
# ## Title :- Exploratory Data Analysis on YouTube data.

# %% [markdown]
# ## Domain:- Social Media

# %% [markdown]
# ## Objective:-

# %% [markdown]
# ###  To do data analysis and explore the youtube dislikes dataset using numpy and pandas libraries and drive meaningful insights by performing Exploratory data analysis.

# %% [markdown]
# ##

# %% [markdown]
# # 1) Importing the Required Libraries for the Datasets

# %%
#Import comment to import libraries that are owned by Python!

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Here we are importing the required libraries to perform various task according to given Datasets

# %% [markdown]
# # 2) Reading the Dataset :-

# %%
# We are going to read the dataset from our local path!

df=pd.read_csv('youtube_dislike_dataset.csv')

# %% [markdown]
# As We have to load a CSV file from our Local Path so we used read Attribute.
# Now we are done with loading our Dataset from our local Directory.

# %% [markdown]
# # Question 01:-

# %% [markdown]
# ###  To retrieve top 5 and bottom 5 records.

# %%
# We are Ready with our Dataset Now we are going to Check for Datas.

df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# Here is our top 5 Records and this is can easily done with the help of Head() Attribute

# %%
# Now we are going to retrieve top 5 bottom Records!

df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# These are the top 5 Bottom Records from our Dataset.This can be Done easily with the help of Tail() Attribute.

# %% [markdown]
# # Question 02:-

# %% [markdown]
# ### To Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
# Now we are done with data loading and Retrieving process and Now are going to check for all the information regarding about the data.

df.shape
# Out:
# (37422, 12)

# %% [markdown]
# Total Data we have in the Dataset is about 37422 and Total Number of Columns we have in the Dataset is about 12 Columns

# %%
# Here we are going to check for Entire Details of Column and its Datatypes!

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# - Here we have 37422 of Datas and 12 Columns
# - And We have 4 int(64) Datatypes and 8 Object Datatypes that are associated with this Dataset

# %%
# Now we are going to list down all the columns that are associated with Dataset!
df.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments'],
#       dtype='object')

# %% [markdown]
# By giving df.columns we can see all the columns that are existed in our Datasets!. This makes better Analysis

# %%
# And we are going to check unique values as additionally for Future Uses!

df.nunique()
# Out:
# video_id         37422
# title            37113
# channel_id       10961
# channel_title    10883
# published_at     36772
# view_count       37256
# likes            32606
# dislikes          9052
# comment_count    13164
# tags             28799
# description      35630
# comments         37264
# dtype: int64

# %% [markdown]
# In this Process we additionally checking for the term unique values that are existed in every Column

# %% [markdown]
# # Question 03:-

# %% [markdown]
# ### To Check for the Percentage of the missing values and drop or impute them.

# %%
# Now we are in the process of finding missing values and dropping those values....etc!
# First we check for any null values in terms of Boolean Values.

df.isnull().values.any()
# Out:
# True

# %% [markdown]
# True Statement Indicates that there are some Null Values in Dataset

# %%
# Now are going to check for Null Values!
pd.DataFrame(df.isnull().sum(),columns=['Number of Missing Values'])
# Out:
#                Number of Missing Values
# video_id                              0
# title                                 0
# channel_id                            0
# channel_title                         0
# published_at                          0
# view_count                            0
# likes                                 0
# dislikes                              0
# comment_count                         0
# tags                                  0
# description                           0
# comments                            158

# %% [markdown]
# In this statement there is a null values in only Comment Column.

# %%
# sum of all null values!
df.isnull().sum().sum()
# Out:
# 158

# %% [markdown]
# Totally there are 158 values noted as null Values

# %% [markdown]
# ### Now we going to Check the Percentage of those Null Values

# %%
df.isnull().sum()/len(df)*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [markdown]
# - There is a null Values in Comment Column
# - And the Percentage of those Null Values in Comment Column is About 42%
# - 42 Percentage of null values are Reported

# %% [markdown]
# ### We have founded there is a Null Values in the Dataset.As we can drop those values or we can impute those values with fillna Attribute.

# %% [markdown]
# #### Here we are going to Drop Those Values

# %%
df1=df.drop(["comments"],axis=1)
df1
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# As we have Successfully Dropped the Comments Column from the Dataset

# %% [markdown]
# # Question 04 :-

# %% [markdown]
# ### To Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
# Here we are going into Statistical part of the Dataset!

df1.describe().transpose()
# Out:
#                  count          mean           std      min       25%  \
# view_count     37422.0  5.697838e+06  2.426622e+07  20368.0  512297.0
# likes          37422.0  1.668147e+05  5.375670e+05      0.0   13233.5
# dislikes       37422.0  4.989862e+03  3.070824e+04      0.0     281.0
# comment_count  37422.0  9.924930e+03  1.171003e+05      0.0     900.0
#
#                      50%         75%           max
# view_count     1319078.5  3670231.25  1.322797e+09
# likes            42330.5   130469.75  3.183768e+07
# dislikes           796.0     2461.75  2.397733e+06
# comment_count     2328.0     6184.00  1.607103e+07

# %% [markdown]
# Here we are checking the statistical Summary for Numerical Variables.
# - View Count has high Mean Value

# %%
# To Generate summary statistical for both categorical and numerical Variables we use to do!

df1.describe(include="all").transpose()
# Out:
#                  count unique                       top  freq            mean  \
# video_id         37422  37422               --0bCF-iK2E     1             NaN
# title            37422  37113                       www    21             NaN
# channel_id       37422  10961  UCNAf1k0yIjyGu3k9BwAg3lg   533             NaN
# channel_title    37422  10883       Sky Sports Football   533             NaN
# published_at     37422  36772       2020-10-16 04:00:10     6             NaN
# view_count     37422.0    NaN                       NaN   NaN  5697837.843996
# likes          37422.0    NaN                       NaN   NaN    166814.74825
# dislikes       37422.0    NaN                       NaN   NaN     4989.861926
# comment_count  37422.0    NaN                       NaN   NaN     9924.929881
# tags             37422  28799                            3817             NaN
# description      37422  35630                             589             NaN
#
# ...

# %% [markdown]
# - By seeing this Summary Statistical we can declare that:-
# - View_count column has maximum Values
# - Likes has mean Value of 166814 which lower than its Standard Deviation as its Std is 537567 which higher than mean
# - Video_id has most number of unique values compared to other columns
# - Dislikes Column has same aspect of Likes column has

# %% [markdown]
# # Question 05 :-

# %% [markdown]
# ### To Convert datatype of column published_at from object to pandas datetime.

# %%
# Now we are going to convert the datatype of published_at from object to datetime!
df1['published_at']=pd.to_datetime(df['published_at'])
df1
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# As here we changed the datatype of the published_at Column from object to pandas datetime format
# Just by Using pd.to_Datetime Attribute

# %% [markdown]
# # Question 06 :-

# %% [markdown]
# ### To Create a new column as 'published_month' using the column published_at (display the months only)

# %%
# In this part we are going to create new column!

df1['published_month']=df1['published_at'].dt.month
df1
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# We Successfully Created  one new Column as Published_Month with the Reference of Published_at Column

# %% [markdown]
# # Question 07 :-

# %% [markdown]
# ### To Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
# Now here we going to make some replacement process!
month_names={1:'Jan',2:'Feb',3:'Mar',4:'Apr',
            5:'May',6:'Jun',7:'Jul',8:'Aug',
             9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

# %%
df1['published_month']=df1['published_month'].map(month_names)
df1
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# Here we are Creating one Dictionary and Marking all the Month as in terms of names and giving each month a key and we replacing published_month as in number format to Name Format just by using map with that Dictionary

# %% [markdown]
# # Question 08 :-

# %% [markdown]
# ### To Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
# In this we are going find number of videos of each month and we are going to arranage them by largest to Smallest!
monthly_video_count=df1['published_month'].value_counts()

# %%
monthly_video_count=monthly_video_count.sort_values(ascending=False)

# %%
monthly_video_count
# Out:
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: published_month, dtype: int64

# %% [markdown]
# In this process first we have counted the value of video for every month and then we just sort those values from largest to smallest according to this Oct,Sep,Nov..... are assigned as they have high value in it

# %% [markdown]
# # Question 09 :-

# %% [markdown]
# ### To Find the count of unique video_id, channel_id and channel_title.

# %%
# as we going to find count of unique video_id,channel_id and channel_title..
unique_video_id=df['video_id'].nunique()
unique_channel_id=df['channel_id'].nunique()
unique_channel_title=df['channel_title'].nunique()

print("Unique Video Id :-",unique_video_id)
print("\r")
print("Unique Channel Id :-",unique_channel_id)
print("\r")
print("Unique Channel Ttile :-",unique_channel_title)
# Out:
# Unique Video Id :- 37422
#
# Unique Channel Id :- 10961
#
# Unique Channel Ttile :- 10883

# %% [markdown]
# In this part we use nunique() Attribute to find unique values to these variables video_id,Channel_id,Channel_title.
# - Video id has 37422 values of uniqueness
# - 10961 values existed in Channel_id
# - 10883 values of record found in Channel_title

# %% [markdown]
# # Question 10 :-

# %% [markdown]
# ### To  Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
# Here we are finding Top 10 Channel Names!
df.channel_title.value_counts().head(10)
# Out:
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: channel_title, dtype: int64

# %%
df.channel_title.value_counts().tail(10)
# Out:
# Eiaz                     1
# adidas                   1
# Universitetet i Agder    1
# Team Tapia               1
# TheVincentMottola        1
# Blocktrainer             1
# Movie Addicts            1
# 1 1 minute mom           1
# FLORIN CERCEL            1
# Master Podcast           1
# Name: channel_title, dtype: int64

# %% [markdown]
# - 1st Code states top 10 Channel Names as this channel has highest number of videos in dataset
# - 2nd Code states low 10 Channel Names as this channel has lowest number of videos in dataset

# %% [markdown]
# # Question 11 :-

# %% [markdown]
# ### To Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
# we are going to find title of video which has maximum likes! and minimum likes!
df.loc[df['likes'].idxmax(),'title']
# Out:
# "BTS () 'Dynamite' Official MV"

# %%
df.loc[df['likes'].idxmin(),'title']
# Out:
# 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'

# %% [markdown]
# - "BTS () 'Dyanmite'Offical MV' is the maximum liked Video
# - " Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News' is minimum liked video

# %% [markdown]
# # Question 12 :-

# %% [markdown]
# ### To Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
# In this part we are going to do opposite action!
df.loc[df['dislikes'].idxmax(),'title']
# Out:
# 'Cuties | Official Trailer | Netflix'

# %%
df.loc[df['dislikes'].idxmin(),'title']
# Out:
# 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'

# %% [markdown]
# - Cuties from Netflix having maximum number of likes in the Dataset
# - Kim Kardashian from E News having minimum number of likes in the Datasets

# %% [markdown]
# # Question 13 :-

# %% [markdown]
# ### Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot ???

# %%
corr=df['view_count'].corr(df['dislikes'])
plt.figure(figsize=(10,6))
plt.scatter(df['view_count'],df['dislikes'],alpha=0.5)
plt.title("Relationship Between View_count and Dislikes")
plt.xlabel("Number of Views")
plt.ylabel("Number of Dislikes")
plt.grid=True
plt.show()

# %% [markdown]
# ### Here the correlation between view_count and dislikes is approxmately 0.68446877

# %% [markdown]
# - correlation coefficient between "view count" and "dislikes" is approximately 0.6845.
# - This shows there is a moderate positive correlation between the number of views and the number of dislikes for the videos.

# %% [markdown]
# # Question 14 :-

# %% [markdown]
# ### Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
# At last we are going to see all the information about the video that were published in january!

jan_videos = df1[df1['published_at'].dt.month == 1]

print("Information about videos published in January:")
print(jan_videos)

jan_video_count = jan_videos.shape[0]
print("\nCount of videos published in January:", jan_video_count)
# Out:
# Information about videos published in January:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %% [markdown]
# ### And the count of videos that are published in the Month of January is about = 2108

# %% [markdown]
# #

# %% [markdown]
# # By Sheik Mohamed.
